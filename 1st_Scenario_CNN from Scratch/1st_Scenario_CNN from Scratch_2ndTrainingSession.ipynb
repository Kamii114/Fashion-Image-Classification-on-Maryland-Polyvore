# %% [markdown]
# # Fashion Image Classification on Maryland Polyvore: First Scenario - CNN from Scratch
#
# ## Authors
# - Kamand Kalashi
# - Sajjad Saed
#
#
# ## Project Overview
# In this project, we embark on the journey of building a Convolutional Neural Network (CNN) from scratch, focusing on image classification within the fashion domain. Our primary objective is to classify images based on distinct categories derived from the Maryland Fashion Dataset, which is publicly available [here](https://github.com/AemikaChow/AiDLab-fAshIon-Data/blob/main/Datasets/cleaned-maryland.md).
#
# ### Dataset
# The dataset consists of a diverse collection of fashion images, each categorized into predefined classes. This diversity allows the CNN to learn and distinguish various fashion items based on their visual features.
#
# ### Methodology
# #### 1. Environment Setup
# We initiate the project by importing essential libraries, including TensorFlow and Keras, which are pivotal for building and training the CNN. Libraries for data manipulation, image processing, and visualization are also included to streamline the workflow.
#
# #### 2. Data Preparation
# Data preparation is a crucial step in any machine learning project. We mount Google Drive to access our dataset efficiently. Then, we retrieve class names from the dataset, providing an overview of the categories we will work with.
#
# We display sample images from each class to visualize the dataset's variety. This step helps in understanding the data and setting expectations for model performance.
#
# #### 3. Image Preprocessing
# To ensure the CNN can process images effectively, we resize all images to a consistent shape (128x128 pixels). Each image is converted to grayscale, and the pixel values are normalized to a range of [0, 1]. This normalization is vital for accelerating convergence during training.
#
# #### 4. Data Augmentation
# To enhance model robustness and reduce overfitting, we apply data augmentation techniques. These techniques include random rotations, shifts, and flips, artificially increasing the diversity of the training dataset.
#
# #### 5. Model Architecture
# We design a custom CNN architecture, employing layers like convolutional, pooling, dropout, and dense layers. The architecture is structured to progressively extract features, reduce dimensionality, and ultimately classify the images into their respective categories. We include dropout layers to mitigate overfitting and enhance generalization.
#
# #### 6. Model Compilation
# The model is compiled with categorical crossentropy as the loss function and Adam as the optimizer. We monitor accuracy as the performance metric, which provides insights into the model's classification capabilities.
#
# #### 7. Model Training
# The model is trained using the training dataset, while the validation dataset allows us to monitor performance and avoid overfitting. We leverage callbacks like EarlyStopping and ReduceLROnPlateau to optimize training efficiency.
#
# #### 8. Model Evaluation
# After training, we evaluate the model on a separate test set to assess its performance. We calculate metrics such as accuracy, loss, and a classification report that provides precision, recall, and F1 scores for each class. Additionally, a confusion matrix is visualized to identify misclassifications, aiding in further model refinement.
#
# ### Training Sessions
# In the repository, we have provided two files from different training sessions. The first training session yielded an accuracy of **84%**, while the second achieved an accuracy of **79%**. Notably, the model with **79% accuracy** exhibited a more stable training and validation accuracy and loss compared to the **84% model**. This observation suggests that while the first model achieved higher accuracy, the second model may generalize better due to its stability during training.
#
# ### Conclusion
# This project illustrates the complete workflow of building a CNN from scratch for image classification. By following this structured approach, we aim to develop a robust model capable of accurately classifying fashion images. The insights gained from the evaluation phase will guide future improvements and iterations of the model.

# %% [markdown]
# ## Step 1: Import Required Libraries
# - Import the necessary libraries for feature extraction, image processing, and model training.

# %%
# Importing required libraries
# Feature extraction and feature selection
import numpy as np
import pandas as pd

# imqage processing and visualization
import cv2
import tqdm as tqdm
from PIL import Image
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Data training and create cnn model
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, MaxPooling2D, GlobalAveragePooling2D, Flatten
from keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix,classification_report
from keras.callbacks import EarlyStopping,ReduceLROnPlateau, TensorBoard, ModelCheckpoint
import itertools
import ipywidgets as widgets

# %% [markdown]
# ## Step 2: Mount Google Drive
# - Mount Google Drive to access the dataset stored in it.

# %%
# Mount Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 3: Dataset Exploration

# %%
dataset_path = '/content/drive/MyDrive/Polyvore/'

# %% [markdown]
# ### 3.1 Get Class Names
# - Retrieve the class names and the count of images in each class from the dataset.

# %%
# return dataset class names and count
def get_class_names(data_path):
    class_names = [f for f in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, f))]
    return class_names

# %%
# get dataset class names and count
class_names = get_class_names(dataset_path)
print("Dataset classes count:", len(class_names)," and names are:", class_names)
# Out:
# Dataset classes count: 8  and names are: ['bag', 'dress', 'eyewear', 'hats', 'neckwear', 'pants', 'shoes', 'watches']

# %% [markdown]
# ### 3.2 Sample Image Display
# - Display a sample image from each class for a quick visual understanding of the dataset.

# %%
# select first image from each class
images = []
for i in class_names:
  path=os.path.join(dataset_path,i)
  label = class_names.index(i)
  img=os.listdir(path)[0]
  try:
    img_arr=cv2.imread(os.path.join(path,img))
    new_img_arr = cv2.resize(img_arr, (128, 128))
    images.append([new_img_arr, label])
  except Exception as e:
    pass

# Display a sample image of each class
rows_num = 2
cols_num = 5
images_num = 8
plt.figure(figsize=(4*cols_num,4*rows_num))
for i in range(images_num):
  plt.subplot(2*rows_num,2*cols_num,2*i+1)
  plt.imshow(images[i][0])
  plt.title(f"Class: {class_names[images[i][1]]}")
  plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Resize Images
# - Resize all images to a uniform size of 128x128 pixels for consistency.

# %%
# to resizing all data to same size (128*128)
image_size = 128
# Array to store all images with its label
all_data = []
image_count = []
count = 0

# For each index in the list of classes (class_names), by using method join with arguments dataset_path and i,
# reads all images of these classes and after resizing to 12*128, store the image with its label in all_data array
for i in class_names:
  path=os.path.join(dataset_path,i)
  class_label = class_names.index(i)
  for image in tqdm.tqdm(os.listdir(path)):
    try:
      image_array=cv2.imread(os.path.join(path,image),cv2.IMREAD_GRAYSCALE)
      new_image_array = cv2.resize(image_array, (image_size, image_size))
      all_data.append([new_image_array, class_label])
      # plt.imshow(new_image_array)
      # plt.show()
      # break
      if os.path.isfile(os.path.join(path,image)):
        count += 1
    except Exception as e:
      pass
  image_count.append([count, class_names[class_label]])
  count = 0
image_count
# Out:
# 100%|██████████| 786/786 [00:14<00:00, 54.32it/s]
# 100%|██████████| 800/800 [00:08<00:00, 92.40it/s]
# 100%|██████████| 780/780 [00:07<00:00, 111.00it/s]
# 100%|██████████| 782/782 [00:08<00:00, 89.49it/s]
# 100%|██████████| 791/791 [00:07<00:00, 101.07it/s]
# 100%|██████████| 793/793 [00:08<00:00, 94.61it/s]
# 100%|██████████| 789/789 [00:09<00:00, 81.70it/s]
# 100%|██████████| 786/786 [00:07<00:00, 104.04it/s]
# [[786, 'bag'],
#  [800, 'dress'],
#  [780, 'eyewear'],
#  [782, 'hats'],
#  [791, 'neckwear'],
#  [793, 'pants'],
#  [789, 'shoes'],
#  [786, 'watches']]

# %%
print(len(all_data))
# Out:
# 6307

# %% [markdown]
# ## Step 4: Data Preparation
# ### 4.1 Split Data
# - Split the dataset into training, validation, and test sets to evaluate the model's performance accurately.

# %%
# split images and labels to X and Y arays
# images
X = []
# labels
Y = []
for i, j in all_data:
  X.append(i)
  Y.append(j)
# reshape images to 128*128 and channel 1 (black & white )
X = np.array(X).reshape(-1, image_size, image_size)
print(X.shape)
# to normalize
X = X/255
X = X.reshape(-1, 128, 128, 1)
print(X.shape)

# Converts class vector (Y) to binary class matrix --> one hot encoding
y_categorical = to_categorical(Y,num_classes = 8)
# Out:
# (6307, 128, 128)
# (6307, 128, 128, 1)

# %%
# split the all_data into 80% train data and 20% test data by random state 42
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size = 0.2, random_state = 42 , shuffle = True)
# split 15% of the train data for validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.15, random_state = 42, shuffle = True)

# %%
print('all data:', len(all_data))
print('total train data:', len(X_train) , 'and shape:', X_train.shape)
print('total validation data:', len(X_val), 'and shape:', X_val.shape)
print('total test data:', len(X_test), 'and shape:', X_test.shape)
# Out:
# all data: 6307
# total train data: 4288 and shape: (4288, 128, 128, 1)
# total validation data: 757 and shape: (757, 128, 128, 1)
# total test data: 1262 and shape: (1262, 128, 128, 1)

# %%
X_train.shape
# Out:
# (4288, 128, 128, 1)

# %% [markdown]
# ### 4.2 Data Augmentation
# - Apply data augmentation techniques to the training set to reduce overfitting and enhance model generalization.

# %%
# Data Preprocessing
# Data augmentation to reduce overfitting
train_generator =ImageDataGenerator(
                                      rotation_range=36,
                                      width_shift_range=0.2,
                                      height_shift_range=0.2,
                                      horizontal_flip=True,
                                      vertical_flip=True,
                                      shear_range=0.2,
                                      zoom_range=0.2,
                                      featurewise_std_normalization=False,
                                      samplewise_center=False,
                                      samplewise_std_normalization=False,
                                      fill_mode='nearest'
  # rotation_range=30,
  # width_shift_range=0.2,
  # height_shift_range=0.2,
  # horizontal_flip=True,
  # shear_range=0.2,
  # zoom_range=0.3,
                                      )

# %% [markdown]
# ## Step 5: Design CNN Architecture
# - Define the architecture of the CNN model, including convolutional layers, pooling layers, dropout layers, and fully connected layers.

# %%
from keras.layers import BatchNormalization
from tensorflow.keras import regularizers
# My CNN architecture
model = Sequential()

model.add(Conv2D(filters = 32, kernel_size = (3, 3), padding = 'Same', activation = 'relu', input_shape = (image_size, image_size, 1)))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters = 64, kernel_size = (3, 3), padding = 'Same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2, 2), strides = (2, 2)))
# model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters = 128, kernel_size = (3, 3), padding = 'Same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2, 2), strides = (2, 2)))
# model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dropout(0.2))  # Dropout to reduce overfitting
# model.add(Dense(256, activation = 'relu', kernel_regularizer=regularizers.l2(0.0001)))
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 128, 128, 32)      320
#
#  max_pooling2d_30 (MaxPooli  (None, 64, 64, 32)        0
#  ng2D)
#
#  batch_normalization_10 (Ba  (None, 64, 64, 32)        128
#  tchNormalization)
#
#  dropout_50 (Dropout)        (None, 64, 64, 32)        0
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 64)        18496
#
#  max_pooling2d_31 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_51 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 128)       73856
#
#  max_pooling2d_32 (MaxPooli  (None, 16, 16, 128)       0
#  ng2D)
#
#  dropout_52 (Dropout)        (None, 16, 16, 128)       0
#
#  flatten_10 (Flatten)        (None, 32768)             0
#
#  dropout_53 (Dropout)        (None, 32768)             0
#
#  dense_20 (Dense)            (None, 256)               8388864
#
#  dropout_54 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 8483720 (32.36 MB)
# Trainable params: 8483656 (32.36 MB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Step 6: Compile the Model
# - Compile the CNN model with an appropriate loss function (categorical crossentropy) and optimizer (Adam).

# %%
# Configures the model for training.
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(lr = 0.001269, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-7), metrics = ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
reduce_learning_rate = ReduceLROnPlateau(monitor = 'val_accuracy', patience = 4, verbose = 1, mode = 'auto', factor = 0.3, min_lr = 0.000001)
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("DL_project_CNN_from_scratch4.h5", monitor = 'val_accuracy', verbose = 1, save_best_only = True, mode = 'auto')
early_stop = EarlyStopping(monitor = 'val_accuracy', patience = 4, mode = 'max')

# %% [markdown]
# ## Step 7: Train the Model
# - Train the CNN model using the training data and validate it with the validation set. Utilize callbacks to monitor performance and adjust learning rates.

# %%
# Train the model with data augmentation
train_generator.fit(X_train)
mycnn_history4 = model.fit_generator(train_generator.flow(X_train, y_train, batch_size = 32),
                              epochs = 50,
                              validation_data = (X_val, y_val),
                              steps_per_epoch = X_train.shape[0] // 32,
                              # validation_steps=X_val.shape[0] // 32,
                              callbacks = [reduce_learning_rate, tensorboard, checkpoint])
# Out:
# Epoch 1/50
# <ipython-input-122-23a17c402013>:3: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 134/134 [==============================] - ETA: 0s - loss: 2.3933 - accuracy: 0.1285
# Epoch 1: val_accuracy improved from -inf to 0.10832, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 12s 73ms/step - loss: 2.3933 - accuracy: 0.1285 - val_loss: 2.0795 - val_accuracy: 0.1083 - lr: 0.0010
# Epoch 2/50
# 134/134 [==============================] - ETA: 0s - loss: 2.0611 - accuracy: 0.1665
# Epoch 2: val_accuracy did not improve from 0.10832
# 134/134 [==============================] - 10s 74ms/step - loss: 2.0611 - accuracy: 0.1665 - val_loss: 2.0788 - val_accuracy: 0.1057 - lr: 0.0010
# Epoch 3/50
# 134/134 [==============================] - ETA: 0s - loss: 1.9768 - accuracy: 0.2206
# Epoch 3: val_accuracy improved from 0.10832 to 0.19287, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 72ms/step - loss: 1.9768 - accuracy: 0.2206 - val_loss: 2.0260 - val_accuracy: 0.1929 - lr: 0.0010
# Epoch 4/50
# 134/134 [==============================] - ETA: 0s - loss: 1.8888 - accuracy: 0.2757
# Epoch 4: val_accuracy improved from 0.19287 to 0.19551, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 58ms/step - loss: 1.8888 - accuracy: 0.2757 - val_loss: 2.0286 - val_accuracy: 0.1955 - lr: 0.0010
# Epoch 5/50
# 134/134 [==============================] - ETA: 0s - loss: 1.8304 - accuracy: 0.3181
# Epoch 5: val_accuracy improved from 0.19551 to 0.26684, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 9s 70ms/step - loss: 1.8304 - accuracy: 0.3181 - val_loss: 1.7971 - val_accuracy: 0.2668 - lr: 0.0010
# Epoch 6/50
# 134/134 [==============================] - ETA: 0s - loss: 1.7167 - accuracy: 0.3573
# Epoch 6: val_accuracy improved from 0.26684 to 0.43197, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 11s 79ms/step - loss: 1.7167 - accuracy: 0.3573 - val_loss: 1.5473 - val_accuracy: 0.4320 - lr: 0.0010
# Epoch 7/50
# 134/134 [==============================] - ETA: 0s - loss: 1.6608 - accuracy: 0.3692
# Epoch 7: val_accuracy did not improve from 0.43197
# 134/134 [==============================] - 10s 71ms/step - loss: 1.6608 - accuracy: 0.3692 - val_loss: 2.0202 - val_accuracy: 0.2127 - lr: 0.0010
# Epoch 8/50
# 134/134 [==============================] - ETA: 0s - loss: 1.6128 - accuracy: 0.3925
# Epoch 8: val_accuracy did not improve from 0.43197
# 134/134 [==============================] - 10s 76ms/step - loss: 1.6128 - accuracy: 0.3925 - val_loss: 1.8376 - val_accuracy: 0.2893 - lr: 0.0010
# Epoch 9/50
# 134/134 [==============================] - ETA: 0s - loss: 1.5731 - accuracy: 0.4114
# Epoch 9: val_accuracy improved from 0.43197 to 0.45575, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 57ms/step - loss: 1.5731 - accuracy: 0.4114 - val_loss: 1.4281 - val_accuracy: 0.4557 - lr: 0.0010
# Epoch 10/50
# 134/134 [==============================] - ETA: 0s - loss: 1.5267 - accuracy: 0.4314
# Epoch 10: val_accuracy improved from 0.45575 to 0.52312, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 74ms/step - loss: 1.5267 - accuracy: 0.4314 - val_loss: 1.3179 - val_accuracy: 0.5231 - lr: 0.0010
# Epoch 11/50
# 134/134 [==============================] - ETA: 0s - loss: 1.5026 - accuracy: 0.4489
# Epoch 11: val_accuracy improved from 0.52312 to 0.53104, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 61ms/step - loss: 1.5026 - accuracy: 0.4489 - val_loss: 1.2682 - val_accuracy: 0.5310 - lr: 0.0010
# Epoch 12/50
# 134/134 [==============================] - ETA: 0s - loss: 1.4406 - accuracy: 0.4466
# Epoch 12: val_accuracy improved from 0.53104 to 0.56539, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 58ms/step - loss: 1.4406 - accuracy: 0.4466 - val_loss: 1.2282 - val_accuracy: 0.5654 - lr: 0.0010
# Epoch 13/50
# 134/134 [==============================] - ETA: 0s - loss: 1.4389 - accuracy: 0.4715
# Epoch 13: val_accuracy improved from 0.56539 to 0.56935, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 73ms/step - loss: 1.4389 - accuracy: 0.4715 - val_loss: 1.1705 - val_accuracy: 0.5694 - lr: 0.0010
# Epoch 14/50
# 134/134 [==============================] - ETA: 0s - loss: 1.3860 - accuracy: 0.4914
# Epoch 14: val_accuracy did not improve from 0.56935
# 134/134 [==============================] - 9s 70ms/step - loss: 1.3860 - accuracy: 0.4914 - val_loss: 1.2718 - val_accuracy: 0.5205 - lr: 0.0010
# Epoch 15/50
# 134/134 [==============================] - ETA: 0s - loss: 1.2844 - accuracy: 0.5252
# Epoch 15: val_accuracy improved from 0.56935 to 0.60502, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 58ms/step - loss: 1.2844 - accuracy: 0.5252 - val_loss: 1.0477 - val_accuracy: 0.6050 - lr: 0.0010
# Epoch 16/50
# 134/134 [==============================] - ETA: 0s - loss: 1.2752 - accuracy: 0.5364
# Epoch 16: val_accuracy improved from 0.60502 to 0.61427, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 75ms/step - loss: 1.2752 - accuracy: 0.5364 - val_loss: 1.0834 - val_accuracy: 0.6143 - lr: 0.0010
# Epoch 17/50
# 134/134 [==============================] - ETA: 0s - loss: 1.2407 - accuracy: 0.5548
# Epoch 17: val_accuracy improved from 0.61427 to 0.61691, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 58ms/step - loss: 1.2407 - accuracy: 0.5548 - val_loss: 1.0607 - val_accuracy: 0.6169 - lr: 0.0010
# Epoch 18/50
# 134/134 [==============================] - ETA: 0s - loss: 1.1744 - accuracy: 0.5828
# Epoch 18: val_accuracy improved from 0.61691 to 0.66579, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 73ms/step - loss: 1.1744 - accuracy: 0.5828 - val_loss: 1.1561 - val_accuracy: 0.6658 - lr: 0.0010
# Epoch 19/50
# 134/134 [==============================] - ETA: 0s - loss: 1.1975 - accuracy: 0.5714
# Epoch 19: val_accuracy did not improve from 0.66579
# 134/134 [==============================] - 10s 71ms/step - loss: 1.1975 - accuracy: 0.5714 - val_loss: 1.1149 - val_accuracy: 0.6011 - lr: 0.0010
# Epoch 20/50
# 133/134 [============================>.] - ETA: 0s - loss: 1.1412 - accuracy: 0.5930
# Epoch 20: val_accuracy did not improve from 0.66579
# 134/134 [==============================] - 7s 55ms/step - loss: 1.1428 - accuracy: 0.5926 - val_loss: 1.0307 - val_accuracy: 0.6526 - lr: 0.0010
# Epoch 21/50
# 134/134 [==============================] - ETA: 0s - loss: 1.1267 - accuracy: 0.6059
# Epoch 21: val_accuracy improved from 0.66579 to 0.68164, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 76ms/step - loss: 1.1267 - accuracy: 0.6059 - val_loss: 0.9395 - val_accuracy: 0.6816 - lr: 0.0010
# Epoch 22/50
# 133/134 [============================>.] - ETA: 0s - loss: 1.1106 - accuracy: 0.6093
# Epoch 22: val_accuracy improved from 0.68164 to 0.71070, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 57ms/step - loss: 1.1116 - accuracy: 0.6091 - val_loss: 0.8687 - val_accuracy: 0.7107 - lr: 0.0010
# Epoch 23/50
# 134/134 [==============================] - ETA: 0s - loss: 1.0842 - accuracy: 0.6222
# Epoch 23: val_accuracy did not improve from 0.71070
# 134/134 [==============================] - 10s 71ms/step - loss: 1.0842 - accuracy: 0.6222 - val_loss: 1.0786 - val_accuracy: 0.6288 - lr: 0.0010
# Epoch 24/50
# 134/134 [==============================] - ETA: 0s - loss: 1.0483 - accuracy: 0.6409
# Epoch 24: val_accuracy did not improve from 0.71070
# 134/134 [==============================] - 9s 65ms/step - loss: 1.0483 - accuracy: 0.6409 - val_loss: 0.9260 - val_accuracy: 0.6737 - lr: 0.0010
# Epoch 25/50
# 134/134 [==============================] - ETA: 0s - loss: 1.0503 - accuracy: 0.6341
# Epoch 25: val_accuracy did not improve from 0.71070
# 134/134 [==============================] - 8s 59ms/step - loss: 1.0503 - accuracy: 0.6341 - val_loss: 1.0449 - val_accuracy: 0.6565 - lr: 0.0010
# Epoch 26/50
# 134/134 [==============================] - ETA: 0s - loss: 1.0205 - accuracy: 0.6467
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 26: val_accuracy did not improve from 0.71070
# 134/134 [==============================] - 10s 72ms/step - loss: 1.0205 - accuracy: 0.6467 - val_loss: 0.8736 - val_accuracy: 0.7081 - lr: 0.0010
# Epoch 27/50
# 134/134 [==============================] - ETA: 0s - loss: 0.9141 - accuracy: 0.6824
# Epoch 27: val_accuracy improved from 0.71070 to 0.75429, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 62ms/step - loss: 0.9141 - accuracy: 0.6824 - val_loss: 0.7687 - val_accuracy: 0.7543 - lr: 3.0000e-04
# Epoch 28/50
# 134/134 [==============================] - ETA: 0s - loss: 0.9083 - accuracy: 0.6919
# Epoch 28: val_accuracy did not improve from 0.75429
# 134/134 [==============================] - 9s 66ms/step - loss: 0.9083 - accuracy: 0.6919 - val_loss: 0.8006 - val_accuracy: 0.7398 - lr: 3.0000e-04
# Epoch 29/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8878 - accuracy: 0.6947
# Epoch 29: val_accuracy improved from 0.75429 to 0.78336, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 10s 75ms/step - loss: 0.8878 - accuracy: 0.6947 - val_loss: 0.7051 - val_accuracy: 0.7834 - lr: 3.0000e-04
# Epoch 30/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8674 - accuracy: 0.7052
# Epoch 30: val_accuracy improved from 0.78336 to 0.78468, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 8s 57ms/step - loss: 0.8674 - accuracy: 0.7052 - val_loss: 0.7179 - val_accuracy: 0.7847 - lr: 3.0000e-04
# Epoch 31/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8670 - accuracy: 0.7027
# Epoch 31: val_accuracy did not improve from 0.78468
# 134/134 [==============================] - 9s 70ms/step - loss: 0.8670 - accuracy: 0.7027 - val_loss: 0.7938 - val_accuracy: 0.7649 - lr: 3.0000e-04
# Epoch 32/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8423 - accuracy: 0.7139
# Epoch 32: val_accuracy did not improve from 0.78468
# 134/134 [==============================] - 8s 63ms/step - loss: 0.8423 - accuracy: 0.7139 - val_loss: 0.9581 - val_accuracy: 0.7054 - lr: 3.0000e-04
# Epoch 33/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8445 - accuracy: 0.7120
# Epoch 33: val_accuracy did not improve from 0.78468
# 134/134 [==============================] - 8s 60ms/step - loss: 0.8445 - accuracy: 0.7120 - val_loss: 0.7611 - val_accuracy: 0.7609 - lr: 3.0000e-04
# Epoch 34/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8458 - accuracy: 0.7160
# Epoch 34: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 34: val_accuracy did not improve from 0.78468
# 134/134 [==============================] - 10s 71ms/step - loss: 0.8458 - accuracy: 0.7160 - val_loss: 0.7033 - val_accuracy: 0.7807 - lr: 3.0000e-04
# Epoch 35/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8195 - accuracy: 0.7253
# Epoch 35: val_accuracy did not improve from 0.78468
# 134/134 [==============================] - 7s 55ms/step - loss: 0.8195 - accuracy: 0.7253 - val_loss: 0.7367 - val_accuracy: 0.7728 - lr: 9.0000e-05
# Epoch 36/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8121 - accuracy: 0.7227
# Epoch 36: val_accuracy did not improve from 0.78468
# 134/134 [==============================] - 10s 72ms/step - loss: 0.8121 - accuracy: 0.7227 - val_loss: 0.7943 - val_accuracy: 0.7649 - lr: 9.0000e-05
# Epoch 37/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.7236
# Epoch 37: val_accuracy improved from 0.78468 to 0.78732, saving model to DL_project_CNN_from_scratch4.h5
# 134/134 [==============================] - 9s 64ms/step - loss: 0.7986 - accuracy: 0.7236 - val_loss: 0.7419 - val_accuracy: 0.7873 - lr: 9.0000e-05
# Epoch 38/50
# 134/134 [==============================] - ETA: 0s - loss: 0.8060 - accuracy: 0.7271
# Epoch 38: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 7s 55ms/step - loss: 0.8060 - accuracy: 0.7271 - val_loss: 0.8118 - val_accuracy: 0.7556 - lr: 9.0000e-05
# Epoch 39/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7868 - accuracy: 0.7313
# Epoch 39: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 10s 71ms/step - loss: 0.7868 - accuracy: 0.7313 - val_loss: 0.7251 - val_accuracy: 0.7860 - lr: 9.0000e-05
# Epoch 40/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7931 - accuracy: 0.7311
# Epoch 40: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 7s 55ms/step - loss: 0.7931 - accuracy: 0.7311 - val_loss: 0.7385 - val_accuracy: 0.7794 - lr: 9.0000e-05
# Epoch 41/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7799 - accuracy: 0.7383
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 41: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 8s 57ms/step - loss: 0.7799 - accuracy: 0.7383 - val_loss: 0.8322 - val_accuracy: 0.7701 - lr: 9.0000e-05
# Epoch 42/50
# 133/134 [============================>.] - ETA: 0s - loss: 0.7752 - accuracy: 0.7260
# Epoch 42: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 9s 71ms/step - loss: 0.7763 - accuracy: 0.7255 - val_loss: 0.7706 - val_accuracy: 0.7820 - lr: 2.7000e-05
# Epoch 43/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7781 - accuracy: 0.7337
# Epoch 43: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 7s 56ms/step - loss: 0.7781 - accuracy: 0.7337 - val_loss: 0.7675 - val_accuracy: 0.7807 - lr: 2.7000e-05
# Epoch 44/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.7397
# Epoch 44: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 10s 73ms/step - loss: 0.7484 - accuracy: 0.7397 - val_loss: 0.7513 - val_accuracy: 0.7834 - lr: 2.7000e-05
# Epoch 45/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7722 - accuracy: 0.7400
# Epoch 45: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 45: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 8s 57ms/step - loss: 0.7722 - accuracy: 0.7400 - val_loss: 0.7687 - val_accuracy: 0.7781 - lr: 2.7000e-05
# Epoch 46/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7566 - accuracy: 0.7353
# Epoch 46: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 7s 55ms/step - loss: 0.7566 - accuracy: 0.7353 - val_loss: 0.7589 - val_accuracy: 0.7768 - lr: 8.1000e-06
# Epoch 47/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7522 - accuracy: 0.7474
# Epoch 47: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 10s 73ms/step - loss: 0.7522 - accuracy: 0.7474 - val_loss: 0.7574 - val_accuracy: 0.7807 - lr: 8.1000e-06
# Epoch 48/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.7400
# Epoch 48: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 7s 55ms/step - loss: 0.7648 - accuracy: 0.7400 - val_loss: 0.7418 - val_accuracy: 0.7847 - lr: 8.1000e-06
# Epoch 49/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7736 - accuracy: 0.7327
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 49: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 9s 70ms/step - loss: 0.7736 - accuracy: 0.7327 - val_loss: 0.7354 - val_accuracy: 0.7873 - lr: 8.1000e-06
# Epoch 50/50
# 134/134 [==============================] - ETA: 0s - loss: 0.7606 - accuracy: 0.7374
# Epoch 50: val_accuracy did not improve from 0.78732
# 134/134 [==============================] - 8s 59ms/step - loss: 0.7606 - accuracy: 0.7374 - val_loss: 0.7474 - val_accuracy: 0.7847 - lr: 2.4300e-06

# %%
# Save the Model
model.save('DL_project_CNN_from_scratch4.h5')

# %%
import matplotlib.pyplot as plt

# Displaying curves of loss and accuracy during training
acc = mycnn_history4.history['accuracy']
val_acc = mycnn_history4.history['val_accuracy']
loss = mycnn_history4.history['loss']
val_loss = mycnn_history4.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot accuracy on the left side
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy', marker='o')
plt.plot(epochs, val_acc, label='Validation Accuracy', marker='o', linestyle='dashed')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss on the right side
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o', linestyle='dashed')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter( y=mycnn_history4.history['val_loss'], mode="lines+markers",
            marker=dict(
                symbol="circle",
                size=9,
                angleref="previous",
            ), name="Validation_loss"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter( y=mycnn_history4.history['loss'], mode="lines+markers",
            marker=dict(
                symbol="circle",
                size=9,
                angleref="previous",
            ), name="Training_loss"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter( y=mycnn_history4.history['val_accuracy'], mode="lines+markers",
            marker=dict(
                symbol="circle",
                size=9,
                angleref="previous",
            ), name="Validation_accuracy"),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter( y=mycnn_history4.history['accuracy'], mode="lines+markers",
            marker=dict(
                symbol="circle",
                size=9,
                angleref="previous",
            ), name="Training_accuracy"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Loss/Accuracy of CNN Model"
)

# Set x-axis title
fig.update_xaxes(title_text="Epoch")

# Set y-axes titles
fig.update_yaxes(title_text="<b>Loss</b>", secondary_y=False)
fig.update_yaxes(title_text="<b>Accuracy</b>", secondary_y=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fcc109c7-796e-4ce8-b81c-f159d7d34168" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcc109c7-796e-4ce8-b81c-f159d7d34168")) {                    Plotly.newPlot(                        "fcc109c7-796e-4ce8-b81c-f159d7d34168",                        [{"marker":{"angleref":"previous","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Validation_loss","y":[2.079482316970825,2.0787606239318848,2.025956392288208,2.02862548828125,1.7970606088638306,1.5473437309265137,2.0201542377471924,1.8376351594924927,1.4280515909194946,1.3179489374160767,1.268207311630249,1.228225827217102,1.1704834699630737,1.2718223333358765,1.047654628753662,1.0834438800811768,1.06071937084198,1.1560932397842407,1.114871859550476,1.030653953552246,0.939479649066925,0.8687008619308472,1.0786499977111816,0.9259524345397949,1.0448721647262573,0.8736098408699036,0.7687450647354126,0.8006221652030945,0.7050957083702087,0.717910885810852,0.7938052415847778,0.9581024646759033,0.7611179947853088,0.7032932639122009,0.7366876602172852,0.7942816019058228,0.7419183850288391,0.8117861151695251,0.7250790596008301,0.7385053038597107,0.8322479128837585,0.7705639004707336,0.7674667239189148,0.7512758374214172,0.7686931490898132,0.7588722109794617,0.7573955059051514,0.7418071031570435,0.7353973388671875,0.7474457025527954],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"angleref":"previous","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Training_loss","y":[2.3933184146881104,2.0611066818237305,1.9767661094665527,1.8888390064239502,1.8304437398910522,1.7166712284088135,1.6608281135559082,1.612829566001892,1.5730875730514526,1.5266696214675903,1.5025743246078491,1.440599799156189,1.438862681388855,1.3859705924987793,1.284449577331543,1.2751706838607788,1.2406920194625854,1.1744056940078735,1.1974979639053345,1.142758846282959,1.1267293691635132,1.1115608215332031,1.0841636657714844,1.048282265663147,1.0503257513046265,1.0205450057983398,0.9140989780426025,0.9082562923431396,0.8878005146980286,0.867371141910553,0.8670125007629395,0.8422845005989075,0.844483494758606,0.8457825183868408,0.8194802403450012,0.8120580911636353,0.7985931038856506,0.8059514760971069,0.7867789268493652,0.7931045293807983,0.7798914313316345,0.776282548904419,0.778084933757782,0.7484103441238403,0.7722208499908447,0.7566398978233337,0.7522268295288086,0.764765202999115,0.773565411567688,0.7606304287910461],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"angleref":"previous","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Validation_accuracy","y":[0.10832232236862183,0.10568031668663025,0.19286657869815826,0.19550858438014984,0.2668428122997284,0.4319683015346527,0.2126816362142563,0.289299875497818,0.4557463526725769,0.5231175422668457,0.5310435891151428,0.5653896927833557,0.5693526864051819,0.5204755663871765,0.6050198078155518,0.6142668724060059,0.616908848285675,0.6657859683036804,0.6010568141937256,0.6525759696960449,0.6816380620002747,0.7107001543045044,0.6287978887557983,0.6737120151519775,0.6565389633178711,0.7080581188201904,0.7542932629585266,0.7397622466087341,0.7833553552627563,0.7846763730049133,0.7648612856864929,0.7054161429405212,0.7608982920646667,0.7807133197784424,0.77278733253479,0.7648612856864929,0.7873183488845825,0.7556142807006836,0.7859973311424255,0.7793923616409302,0.7701452970504761,0.7820343375205994,0.7807133197784424,0.7833553552627563,0.7780713438987732,0.7767503261566162,0.7807133197784424,0.7846763730049133,0.7873183488845825,0.7846763730049133],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"angleref":"previous","size":9,"symbol":"circle"},"mode":"lines+markers","name":"Training_accuracy","y":[0.1284981369972229,0. ...

# %% [markdown]
# ## Step 8: Evaluate the Model
# ### 8.1 Model Evaluation
# - Evaluate the model's performance on the test set, calculating accuracy and loss.

# %%
# Evaluate the model  --> first method
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis = 1)
y_real = np.argmax(y_test, axis = 1)

# display result of evaluate the model  --> first method
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy: {:.2f}%".format(test_acc * 100))
print(f"Test loss: {test_loss: 0.2f}")

# display result of evaluate the model  --> first method
accuracy = np.sum(y_pred == y_real) / len(y_test)
print("Test accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 40/40 [==============================] - 0s 5ms/step
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7026 - accuracy: 0.7639
# Test accuracy: 76.39%
# Test loss:  0.70
# Test accuracy: 76.39%

# %%
print(classification_report(y_real, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#          bag       0.67      0.86      0.75       178
#        dress       0.71      0.71      0.71       160
#      eyewear       0.86      0.99      0.92       139
#         hats       0.80      0.83      0.82       152
#     neckwear       0.91      0.47      0.62       167
#        pants       0.98      0.94      0.96       147
#        shoes       0.76      0.47      0.58       168
#      watches       0.62      0.92      0.74       151
#
#     accuracy                           0.76      1262
#    macro avg       0.79      0.77      0.76      1262
# weighted avg       0.78      0.76      0.75      1262

# %% [markdown]
# ### 8.2 Confusion Matrix
# - Create and display a confusion matrix to visualize the model's classification performance across different classes.

# %%
# display confusion matrix
fig, ax = plt.subplots(1,1,figsize=(14, 6))
sns.heatmap(confusion_matrix(y_real, y_pred), xticklabels=class_names, yticklabels=class_names,annot=True, linewidths=2, linecolor='white', ax=ax)
fig.text(s="Confusion Matrix", size=18,fontweight='bold', fontname='DejaVu Sans', y=0.88,x=0.30,alpha=0.8)
bottom, top = plt.ylim()
plt.ylim(bottom + 0.5, top - 0.5)
plt.xlabel('Predicted', color='blue')
plt.ylabel('Real', color='green')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
# plt.show()

# %% [markdown]
# ## Conclusion
# - Summarize the results, discussing the model's effectiveness in classifying images and suggesting future improvements or experiments.
